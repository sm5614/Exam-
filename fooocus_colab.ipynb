# %% [markdown]
# <a href="https://colab.research.google.com/github/sm5614/Exam-/blob/main/fooocus_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pygit2==1.15.1
# %cd /content
# !git clone https://github.com/lllyasviel/Fooocus.git
# %cd /content/Fooocus
# !python entry_with_update.py --share --always-high-vram

# %%
# ১. সঠিক জায়গায় যাওয়া এবং পুরনো ভুল ফাইল মোছা
# %cd /content
# !rm -rf Fooocus github.com

# ২. Fooocus ক্লোন করা
# !git clone https://github.com
# %cd Fooocus

# ৩. লাইব্রেরি ইনস্টল (নতুন নিয়মে যা কোলাব মানবে)
# !pip install pygit2==1.15.1
# !pip install numpy<2.0 # কোলাবকে ২.০ এর নিচের ভার্সন নিতে বাধ্য করা

# ৪. সরাসরি রান করা
# !python entry_with_update.py --share --always-high-vram
# Out:
# /content
# Cloning into 'github.com'...
# fatal: repository 'https://github.com/' not found
# [Errno 2] No such file or directory: 'Fooocus'
# /content
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 48.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pygit2
#     Found existing installation: pygit2 1.19.2
#     Uninstalling pygit2-1.19.2:
#       Successfully uninstalled pygit2-1.19.2
# ...
# /bin/bash: line 1: 2.0: No such file or directory
# python3: can't open file '/content/entry_with_update.py': [Errno 2] No such file or directory
